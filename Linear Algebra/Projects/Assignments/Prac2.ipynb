# %%
"""
  We use the upper Hessenberg Frank matrix
        A[i,j] =     0     for j < i-1, 
                 n+1-i     for j = i-1 
                 n+1-j     for j \geq i              

  to illustrate the role of the condition number and its relation with the
  loss of accuracy when solving linear systems 
  (due to rounding errors, independently of the method used!)

  Remark: det(A)=1 but it is ill-conditioned!

  Explanation: Backward error analysis formula 
               (we assume Delta_A =0, and that there is only representation error in b)
"""

import numpy as np

def frank(n):
  A = np.zeros((n,n))

  for i in range (0,n):
    for j in range (0,n):
      if(i<=j):
        A[i,j] = float(n-j)
      elif(j==i-1):
        A[i,j] = float(n-j-1)

  return A



"""
  MAIN
"""

n=5;
f=frank(n)
print(f)
print(np.linalg.det(f))


print('\n Condition number, upper Hessenberg FRANK matrix\n')

nmin,nmax=map(int,input(' nmin,nmax?\n').split());

eps=1.e-18  #we assume that the error in b is Delta_b = eps_machine (double precision, internal precision)

outfile = open("frank.out","w")

print('n \t cond(A) \t\t eps*cond(A) \t\t xsol-x \n'); 
for n in range (nmin,nmax+1):
   A=frank(n)

   x=np.ones(n)
   b=np.dot(A,x)
   xsol=np.linalg.solve(A,b) ### We ignore the error of the gaussian elimination
   print('%2d %24.16e %24.16e %24.16e' % (n,np.linalg.cond(A),eps*np.linalg.cond(A), np.linalg.norm(xsol-x)/np.linalg.norm(x)))
   outfile.write('%2d %24.16e %24.16e %24.16e\n' % (n,np.linalg.cond(A),eps*np.linalg.cond(A), np.linalg.norm(xsol-x)/np.linalg.norm(x)))

outfile.close()
# Out:
# [[5. 4. 3. 2. 1.]
#  [4. 4. 3. 2. 1.]
#  [0. 3. 3. 2. 1.]
#  [0. 0. 2. 2. 1.]
#  [0. 0. 0. 1. 1.]]
# 1.000000000000003
#
#  Condition number, upper Hessenberg FRANK matrix
#
#  nmin,nmax?
# 2,4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/df/4599m83s2vj4j1_h__gx7kqw0000gn/T/ipykernel_10194/2473768231.py in <module>
#      43 print('\n Condition number, upper Hessenberg FRANK matrix\n')
#      44
# ---> 45 nmin,nmax=map(int,input(' nmin,nmax?\n').split());
#      46
#      47 eps=1.e-18  #we assume that the error in b is Delta_b = eps_machine (double precision, internal precision)
#
# ValueError: invalid literal for int() with base 10: '2,4'

# %%
import numpy as np

outfile = open("hilbert.out","w")

for n in range (2,30):
    A=np.zeros((n,n))
    for i in range(0,n):
        for j in range (0,n):
            A[i,j]=1./(i+j+1)

    kA=np.linalg.norm(A,2)*np.linalg.norm(np.linalg.inv(A),2)
    kkA=np.linalg.cond(A,2)
    print('%2d %24.16e %24.16e\n' %(n,kA,kkA))
    outfile.write('%2d %24.16e %24.16e\n' % (n,kA,kkA))

outfile.close()
# Out:
#  2   1.9281470067903975e+01   1.9281470067903971e+01
#
#  3   5.2405677758606271e+02   5.2405677758606441e+02
#
#  4   1.5513738738933602e+04   1.5513738738929240e+04
#
#  5   4.7660725024576450e+05   4.7660725024259434e+05
#
#  6   1.4951058642074950e+07   1.4951058642254665e+07
#
#  7   4.7536735646774173e+08   4.7536735658312899e+08
#
#  8   1.5257576321957926e+10   1.5257575538060041e+10
#
#  9   4.9315378601241656e+11   4.9315375644687622e+11
#
# 10   1.6026019477413041e+13   1.6024416992541715e+13
#
# 11   5.2342065664873800e+14   5.2226779392803350e+14
#
# 12   1.7715806936210972e+16   1.7514731907091464e+16
#
# 13   3.3028536593780403e+17   3.3441434973384612e+18
#
# 14   4.3544723094505190e+17   6.2007862631614438e+17
#
# 15   4.3803470904383226e+17   3.6743929534679738e+17
#
# 16   3.1464399162753464e+18   7.8654677784316454e+17
#
# 17   9.5904030774353024e+17   1.2636843426660521e+18
#
# 18   7.0406149242160448e+17   2.2446309929189128e+18
#
# 19   7.4602581749320192e+17   6.4719539765415905e+18
#
# 20   2.0859944216801879e+18   1.3553657908688225e+18
#
# 21   2.5506466178993106e+18   3.2901263286013988e+18
#
# 22   1.5380937814544512e+18   1.0361032753348465e+19
#
# 23   1.0210321116999487e+18   6.3137786707246707e+17
#
# 24   1.7322055247376986e+19   2.1295026673381340e+18
#
# 25   1.8794667992381827e+18   1.3719347461445998e+18
#
# 26   2.3860596226532419e+18   5.8386367052193280e+18
#
# 27   1.0207986456449212e+20   4.4245878773615831e+18
#
# 28   1.7115526247335235e+18   9.2353242451613737e+18
#
# 29   4.4535026974124037e+18   8.0592620035276698e+18

# %%
"""
  We compare the efectivenes of solving Ax=b using
  1) x=A^{-1} b
  2) GEPP (Gaussian ellimination with partial pivoting)
"""

import numpy as np

n=25     #dimension
nsys=50  #number of systems

nor1=np.zeros(nsys) #norm-wise relative error for each system using A^-1 to solve it
nor2=np.zeros(nsys) #norm-wise relative error for each system using GEPP to solve it

for isys in range (0,nsys):
    A=np.zeros((n,n))
    Q=np.zeros((n,n))
    x=np.random.normal(0,1,n)
    
    for i in range (0,n):
        for j in range (0,n):
            A[i,j]=np.random.normal(0,1)
    
    Q,R=np.linalg.qr(A)
    D=np.eye(n)         #Returns a 2d array with ones in the diagonal and zeros outside
    D[0,0]=9e7          #Value of the condition number 
    A=np.dot(np.dot(Q.T,D),Q)
    b=np.dot(A,x)
   
    
    iA=np.linalg.inv(A); x1=np.dot(iA,b)   #Direct inversion method
    x2=np.linalg.solve(A,b)                #GEPP (computes LU factorization and solves the linear system)
    
    r1=np.dot(A,x1)-b;  r2=np.dot(A,x2)-b  #residues
    nr1=np.linalg.norm(r1,np.inf);  nr2=np.linalg.norm(r2,np.inf)  #residue norms
    nA=np.linalg.norm(A,np.inf)  #norm of A
    nb=np.linalg.norm(b,np.inf)  #norm of b
    nx1=np.linalg.norm(x1,np.inf);  nx2=np.linalg.norm(x2,np.inf)  #solution norms
    nor1[isys]=nr1/(nA*nx1+nb);  nor2[isys]=nr2/(nA*nx2+nb)  #array of normwise backward errors

print(nor1)
print(nor2)
print('\n Direct invert method solutions, min and max normwise backward error: \n %24.16e %24.16e \n\n GEPP (LU), min and max normwise backward error: \n %24.16e %24.16e\n' % (np.amin(nor1), np.amax(nor1), np.amin(nor2), np.amax(nor2)))
# Out:
# [4.60866498e-11 2.01361728e-11 2.14757560e-10 3.25169569e-11
#  4.85564162e-10 8.86339022e-11 1.15987631e-10 5.72879790e-12
#  1.02969977e-11 2.37963914e-10 1.41138121e-10 3.69860670e-11
#  1.48055384e-12 3.02987839e-11 1.99868180e-10 9.69281392e-11
#  4.21828235e-12 4.35849950e-10 7.64353354e-11 8.16790259e-11
#  4.35089615e-10 3.91973658e-10 2.20050832e-10 7.35515376e-11
#  2.30575062e-11 3.30031736e-10 6.93422944e-12 9.03239437e-10
#  9.11767870e-12 1.03460647e-09 5.39238196e-10 1.96234066e-10
#  2.52961292e-10 5.47148536e-10 1.31546118e-11 2.31536362e-11
#  2.11687471e-10 3.86702352e-10 8.88234583e-11 3.78821529e-11
#  6.35998435e-10 1.38302351e-09 7.85872279e-11 1.63852871e-11
#  5.14096018e-10 2.91215505e-10 5.82591597e-10 7.59383858e-11
#  1.91921878e-10 3.20356995e-11]
# [8.75225773e-18 2.03627559e-17 8.37468411e-18 2.05475350e-17
#  3.66923114e-17 1.95324457e-17 2.07129203e-17 2.62494491e-17
#  1.27769321e-17 1.52393501e-17 2.04976046e-17 8.65799430e-18
#  7.48980069e-18 2.71616901e-17 2.28323785e-17 1.47878460e-17
#  1.20029261e-17 3.05318882e-17 7.02881663e-17 2.31518184e-17
#  1.81590573e-17 2.63037993e-17 1.94343125e-17 1.56056593e-17
#  8.27311535e-18 3.61714885e-17 2.01284808e-17 6.81979403e-17
#  2.42228611e-17 4.18477876e-17 2.14322909e-17 1.51930625e-17
#  2.08912146e-17 3.76593462e-17 2.94858526e-17 1.05436724e-17
#  2.39798605e-17 1.45857830e-17 2.89190826e-17 4.30159857e-17
#  7.23168797e-18 6.60487092e-17 3.28879636e-17 1.76636836e-17
#  3.57399680e-17 6.28340453e-17 1.97271918e-17 2.29764954e-17
#  1.75303492e-17 3.57407859e-17]
#
#  Direct invert method solutions, min and max normwise backward error:
#    1.4805538413972693e-12   1.3830235116006176e-09
#
#  GEPP (LU), min and max normwise backward error:
#    7.2316879700277117e-18   7.0288166297572357e-17

# %%
"""
  We compare the efectivenes of solving Ax=b using
  1) x=A^{-1} b
  2) GEPP (Gaussian ellimination with partial pivoting)
"""

import numpy as np
import time

ini=time.perf_counter()

nmax=100
nsys=10000

outfile=open("inv_time.out","w");
    
outfile.write('# n = dimension\n') 
outfile.write('# t1 = direct inversion method time (in sec) for solving %d systems of dimension n\n' % (nsys)) 
outfile.write('# t2 = Gauss (LU) time (in sec) for solving %d systems of dimension n\n' % (nsys)) 
outfile.write('# file: n t1 t2\n')

for n in range (2,nmax):
    print("# starting n=%d" % (n))
    Alist=np.zeros((nsys,n,n))
    for isys in range (0,nsys):
        A=np.zeros((n,n))
        Q=np.zeros((n,n))
        x=np.random.normal(0,1,n)
        
        for i in range (0,n):
            for j in range (0,n):
                A[i,j]=np.random.normal(0,1)
        
        Q,R=np.linalg.qr(A)
        B=np.eye(n)         #Returns a 2d array with ones in the diagonal and zeros outside
        B[0,0]=9e7          #Value of the condition number 
        Alist[isys]=np.dot(np.dot(Q.T,B),Q)
        b=np.dot(Alist[isys],x)
        
    print("# %d systems of dimension %d with k(A)=%e have been randomly generated" % (nsys,n,B[0,0]))
    start1 = time.perf_counter()
    for isys in range (0,nsys):
        iA=np.linalg.inv(Alist[isys]); x1=np.dot(iA,b)   #Direct inversion method
    end1 = time.perf_counter()
    
    start2 = time.perf_counter()
    for isys in range (0,nsys):
        x2=np.linalg.solve(Alist[isys],b)                #GEPP (computes LU factorization and solves the linear system)
    end2 = time.perf_counter()
    print('%d %24.16e %24.16e \n ' % (n,end1 -start1,end2-start2))
    outfile.write('%d %24.16e %24.16e\n' % (n,end1 -start1,end2-start2))
        

fin = time.perf_counter()
outfile.write('#Total time (sec): %24.16e\n' % (fin -ini))
outfile.close()
# Out:
# # starting n=2
# # 10000 systems of dimension 2 with k(A)=9.000000e+07 have been randomly generated
# 2   1.7471560900000327e-01   1.2042008200000964e-01
#
# # starting n=3
# # 10000 systems of dimension 3 with k(A)=9.000000e+07 have been randomly generated
# 3   1.8010480500001336e-01   1.0502370399998995e-01
#
# # starting n=4
# # 10000 systems of dimension 4 with k(A)=9.000000e+07 have been randomly generated
# 4   2.1172481499999662e-01   1.0858569900000248e-01
#
# # starting n=5
# # 10000 systems of dimension 5 with k(A)=9.000000e+07 have been randomly generated
# 5   2.1306063599999447e-01   1.3989321700000801e-01
#
# # starting n=6
# # 10000 systems of dimension 6 with k(A)=9.000000e+07 have been randomly generated
# 6   2.2230403699998647e-01   1.4478632699999139e-01
#
# # starting n=7
# # 10000 systems of dimension 7 with k(A)=9.000000e+07 have been randomly generated
# 7   2.3993757100001289e-01   1.3933346799998958e-01
#
# # starting n=8
# # 10000 systems of dimension 8 with k(A)=9.000000e+07 have been randomly generated
# 8   2.0816924100000733e-01   1.3667397599999731e-01
#
# # starting n=9
# # 10000 systems of dimension 9 with k(A)=9.000000e+07 have been randomly generated
# 9   1.8944636099999457e-01   1.5828067799998280e-01
#
# # starting n=10
# # 10000 systems of dimension 10 with k(A)=9.000000e+07 have been randomly generated
# 10   2.4347759399998381e-01   1.7171660100001418e-01
#
# # starting n=11
# # 10000 systems of dimension 11 with k(A)=9.000000e+07 have been randomly generated
# 11   2.4449627800001394e-01   1.4077041499999154e-01
#
# # starting n=12
# # 10000 systems of dimension 12 with k(A)=9.000000e+07 have been randomly generated
# 12   2.2061739599999441e-01   1.4578549600000201e-01
#
# # starting n=13
# # 10000 systems of dimension 13 with k(A)=9.000000e+07 have been randomly generated
# 13   2.4003577299998824e-01   1.4862333100001024e-01
#
# # starting n=14
# # 10000 systems of dimension 14 with k(A)=9.000000e+07 have been randomly generated
# 14   2.4657876200001283e-01   1.5116150599999401e-01
#
# # starting n=15
# # 10000 systems of dimension 15 with k(A)=9.000000e+07 have been randomly generated
# 15   3.1206021099998793e-01   1.4472617199999149e-01
#
# # starting n=16
# # 10000 systems of dimension 16 with k(A)=9.000000e+07 have been randomly generated
# 16   2.9412224099999662e-01   1.6448878700001046e-01
#
# # starting n=17
# # 10000 systems of dimension 17 with k(A)=9.000000e+07 have been randomly generated
# 17   3.0789083100000880e-01   1.6089928099998474e-01
#
# # starting n=18
# # 10000 systems of dimension 18 with k(A)=9.000000e+07 have been randomly generated
# 18   3.6012393199999337e-01   2.0118384599999217e-01
#
# # starting n=19
# # 10000 systems of dimension 19 with k(A)=9.000000e+07 have been randomly generated
# 19   3.1529411099998583e-01   2.1525821200000905e-01
#
# # starting n=20
# # 10000 systems of dimension 20 with k(A)=9.000000e+07 have been randomly generated
# 20   3.7741743299997665e-01   2.6439271700002109e-01
#
# # starting n=21
# # 10000 systems of dimension 21 with k(A)=9.000000e+07 have been randomly generated
# 21   5.0647741899996390e-01   2.6721159999999600e-01
#
# # starting n=22
# # 10000 systems of dimension 22 with k(A)=9.000000e+07 have been randomly generated
# 22   3.8933987899997646e-01   2.3731377100000373e-01
#
# # starting n=23
# # 10000 systems of dimension 23 with k(A)=9.000000e+07 have been randomly generated
# 23   4.6186330000000453e-01   2.7712941400000091e-01
#
# # starting n=24
# # 10000 systems of dimension 24 with k(A)=9.000000e+07 have been randomly generated
# 24   3.3072354600000153e-01   2.1800171899997167e-01
#
# # starting n=25
# # 10000 systems of dimension 25 with k(A)=9.000000e+07 have been randomly generated
# 25   3.7398434900001121e-01   2.3805579599996918e-01
#
# # starting n=26
# # 10000 systems of dimension 26 with k(A)=9.000000e+07 have been randomly generated
# 26   3.8139122900003031e-01   2.3602108900001895e-01
#
# # starting n=27
# # 10000 systems of dimension 27 with k(A)=9.000000e+07 have been randomly generated
# 27   3.9310620200001267e-01   2.4395028700001831e-01
#
# # starting n=28
# # 10000 systems of dimension 28 with k(A)=9.000000e+07 have been randomly generated
# 28   4.0839879200001405e-01   2.4983584300002804e-01
#
# # starting n=29
# # 10000 systems of dimension 29 with k(A)=9.000000e+07 have been randomly generated
# 29   4.1878629799998635e-01   2.5823962799995570e-01
#
# # starting n=30
# # 10000 systems of dimension 30 with k(A)=9.000000e+07 have been randomly generated
# 30   4.8693929299997762e-01   2.6699091800003316e-01
#
# # starting n=31
# # 10000 systems of dimension 31 with k(A)=9.000000e+07 have been randomly generated
# 31   4.5930326000001287e-01   2.7289025800001809e-01
#
# # starting n=32
# # 10000 systems of dimension 32 with k(A)=9.000000e+07 have been randomly generated
# 32   4.2707125099997256e-01   2.7088328899998260e-01
#
# # starting n=33
# # 10000 systems of dimension 33 with k(A)=9.000000e+07 have been randomly generated
# 33   4.8086076699996738e-01   3.1392878999997720e-01
#
# # starting n=34
# # 10000 systems of dimension 34 with k(A)=9.000000e+07 have been randomly generated
# 34   7.5121810400003142e-01   4.4015784300000860e-01
#
# # starting n=35
# # 10000 systems of dimension 35 with k(A)=9.000000e+07 have been randomly generated
# 35   6.3601991200005159e-01   4.8713035700001228e-01
#
# # starting n=36
# # 10000 systems of dimension 36 with k(A)=9.000000e+07 have been randomly generated
# 36   6.6919550299996899e-01   4.6922014499995157e-01
#
# # starting n=37
# # 10000 systems of dimension 37 with k(A)=9.000000e+07 have been randomly generated
# 37   1.0170139839999592e+00   3.6660299100003613e-01
#
# # starting n=38
# # 10000 systems of dimension 38 with k(A)=9.000000e+07 have been randomly generated
# 38   5.5518564399994830e-01   3.3437450200005969e-01
#
# # starting n=39
# # 10000 systems of dimension 39 with k(A)=9.000000e+07 have been randomly generated
# 39   6.6628368500005308e-01   3.6176671199996235e-01
#
# # starting n=40
# # 10000 systems of dimension 40 with k(A)=9.000000e+07 have been randomly generated
# 40   6.0663417899991146e-01   3.6915771199994651e-01
#
# # starting n=41
# # 10000 systems of dimension 41 with k(A)=9.000000e+07 have been randomly generated
# 41   9.4061212400004024e-01   3.8891098300007343e-01
#
# # starting n=42
# # 10000 systems of dimension 42 with k(A)=9.000000e+07 have been randomly generated
# 42   6.3107581500003107e-01   3.9286029200002304e-01
#
# # starting n=43
# # 10000 systems of dimension 43 with k(A)=9.000000e+07 have been randomly generated
# 43   6.6914392000001044e-01   4.0965747699999611e-01
#
# # starting n=44
# # 10000 systems of dimension 44 with k(A)=9.000000e+07 have been randomly generated
# 44   7.8358573799994247e-01   4.5542569700000968e-01
#
# # starting n=45
# # 10000 systems of dimension 45 with k(A)=9.000000e+07 have been randomly generated
# 45   7.1291691800001900e-01   4.3967539799996302e-01
#
# # starting n=46
# # 10000 systems of dimension 46 with k(A)=9.000000e+07 have been randomly generated
# 46   7.8060029300002043e-01   4.4283391999999822e-01
#
# # starting n=47
# # 10000 systems of dimension 47 with k(A)=9.000000e+07 have been randomly generated
# 47   9.2320742499998687e-01   5.0492256799998358e-01
#
# # starting n=48
# # 10000 systems of dimension 48 with k(A)=9.000000e+07 have been randomly generated
# 48   7.4368901099990126e-01   4.6417659199994432e-01
#
# # starting n=49
# # 10000 systems of dimension 49 with k(A)=9.000000e+07 have been randomly generated
# 49   9.3992870200008838e-01   5.3111551500001042e-01
#
# # starting n=50
# # 10000 systems of dimension 50 with k(A)=9.000000e+07 have been randomly generated
# 50   9.4339097099998526e-01   5.8633356600000752e-01
#
# # starting n=51
# # 10000 systems of dimension 51 with k(A)=9.000000e+07 have been randomly generated
# 51   1.0351256499999408e+00   5.4608187900009852e-01
#
# # starting n=52
# # 10000 systems of dimension 52 with k(A)=9.000000e+07 have been randomly generated
# 52   8.7174980100007815e-01   5.0286823200008257e-01
#
# # starting n=53
# # 10000 systems of dimension 53 with k(A)=9.000000e+07 have been randomly generated
# 53   1.0270643169999403e+00   6.5025827199997366e-01
#
# # starting n=54
# # 10000 systems of dimension 54 with k(A)=9.000000e+07 have been randomly generated
# 54   9.3760299800010216e-01   5.0625055800014707e-01
#
# # starting n=55
# # 10000 systems of dimension 55 with k(A)=9.000000e+07 have been randomly generated
# 55   9.9167688500006079e-01   5.3059729599999628e-01
#
# # starting n=56
# # 10000 systems of dimension 56 with k(A)=9.000000e+07 have been randomly generated
# 56   9.8553042999992613e-01   5.4797983499997827e-01
#
# # starting n=57
# # 10000 systems of dimension 57 with k(A)=9.000000e+07 have been randomly generated
# 57   1.2333306570001241e+00   9.2577499300000454e-01
#
# # starting n=58
# # 10000 systems of dimension 58 with k(A)=9.000000e+07 have been randomly generated
# 58   1.5189711199998328e+00   7.3959559499985517e-01
#
# # starting n=59
# # 10000 systems of dimension 59 with k(A)=9.000000e+07 have been randomly generated
# 59   1.2752329519998966e+00   6.5480881700000282e-01
#
# # starting n=60
# # 10000 systems of dimension 60 with k(A)=9.000000e+07 have been randomly generated
# 60   1.2658921359998203e+00   6.1514139099995191e-01
#
# # starting n=61
# # 10000 systems of dimension 61 with k(A)=9.000000e+07 have been randomly generated
# 61   2.0344735109999874e+00   7.9404067699988445e-01
#
# # starting n=62
# # 10000 systems of dimension 62 with k(A)=9.000000e+07 have been randomly generated
# 62   2.4832309619998796e+00   1.0365769290001481e+00
#
# # starting n=63
# # 10000 systems of dimension 63 with k(A)=9.000000e+07 have been randomly generated
# 63   1.4899715490000744e+00   7.0545373899994956e-01
#
# # starting n=64
# # 10000 systems of dimension 64 with k(A)=9.000000e+07 have been randomly generated
# 64   1.4135658590000730e+00   1.0107759540001098e+00
#
# # starting n=65
# # 10000 systems of dimension 65 with k(A)=9.000000e+07 have been randomly generated
# 65   1.2660849900000812e+00   6.9075701000019762e-01
#
# # starting n=66
# # 10000 systems of dimension 66 with k(A)=9.000000e+07 have been randomly generated
# 66   1.4606897189999017e+00   8.2826704100011739e-01
#
# # starting n=67
# # 10000 systems of dimension 67 with k(A)=9.000000e+07 have been randomly generated
# 67   1.4189506979998896e+00   7.4042254200003299e-01
#
# # starting n=68
# # 10000 systems of dimension 68 with k(A)=9.000000e+07 have been randomly generated
# 68   2.6657001370003854e+00   1.1767801969999709e+00
#
# # starting n=69
# # 10000 systems of dimension 69 with k(A)=9.000000e+07 have been randomly generated
# 69   1.4490199060001032e+00   7.7923576400007732e-01
#
# # starting n=70
# # 10000 systems of dimension 70 with k(A)=9.000000e+07 have been randomly generated
# 70   2.0790865149997444e+00   9.2213387799984048e-01
#
# # starting n=71
# # 10000 systems of dimension 71 with k(A)=9.000000e+07 have been randomly generated
# 71   1.5144857650002450e+00   8.1518391800000245e-01
#
# # starting n=72
# # 10000 systems of dimension 72 with k(A)=9.000000e+07 have been randomly generated
# 72   1.5572493849999773e+00   7.8074749699999302e-01
#
# # starting n=73
# # 10000 systems of dimension 73 with k(A)=9.000000e+07 have been randomly generated
# 73   2.1923916670002654e+00   1.0605250029998388e+00
#
# # starting n=74
# # 10000 systems of dimension 74 with k(A)=9.000000e+07 have been randomly generated
# 74   2.2214866899998924e+00   1.0575920919995951e+00
#
# # starting n=75
# # 10000 systems of dimension 75 with k(A)=9.000000e+07 have been randomly generated
# 75   1.6674981309997747e+00   1.0604863690000457e+00
#
# # starting n=76
# # 10000 systems of dimension 76 with k(A)=9.000000e+07 have been randomly generated
# 76   1.7637826710001718e+00   9.1997015400011151e-01
#
# # starting n=77
# # 10000 systems of dimension 77 with k(A)=9.000000e+07 have been randomly generated
# 77   1.7237537210003211e+00   8.8619874100004381e-01
#
# # starting n=78
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/df/4599m83s2vj4j1_h__gx7kqw0000gn/T/ipykernel_10194/2472820749.py in <module>
#      30         for i in range (0,n):
#      31             for j in range (0,n):
# ---> 32                 A[i,j]=np.random.normal(0,1)
#      33
#      34         Q,R=np.linalg.qr(A)
#
# KeyboardInterrupt:

# %%
import numpy as np

outfile=open("vander.out","w")

for n in range (2,51):
    alph=np.zeros(n)
    for j in range (1,n+1):
        alph[j-1] = 1-2.*(j-1)/(n-1)
    
    V=np.zeros((n,n))
    for i in range (0,n):
        for j in range (0,n):
            V[i,j] = alph[j]**i

    print(V)
    kV=np.linalg.norm(V,2)*np.linalg.norm(np.linalg.inv(V),2)
    print('%2d %24.16e\n'%(n,kV))
    outfile.write('%2d %24.16e %24.16e\n' %(n,np.linalg.norm(V,2),kV))

outfile.close()
