# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# Flàvia Ferrús and David Rosado

# %% [markdown]
# # Robust linear regression

# %% [markdown]
# ## 1.Introduction

# %% [markdown]
# ### 1.Implement the method proposed with gradient descent and backtracking (or a small constant $\alpha$ value).

# %%
#Randomly generated set of points
m = [0.,0.]
angle = 45*math.pi/180
rot = np.array([[math.cos(angle), -math.sin(angle)], [math.sin(angle),
math.cos(angle)]])
lamb = np.array([[100,0],[0,1]])
s = np.matmul(rot, np.matmul(lamb, rot.transpose()))
points = np.random.multivariate_normal(m,s,100)
plt.scatter(points[:,0],points[:,1])

# %% [markdown]
# Let us define the function and its gradient

# %%
#Definitions of the functions we need
def Q(w0, w1):
    return (1/2) * np.sum((w0 * points[:,0] + w1 - points[:,1])**2)

def grad_Q(w0, w1):
    return np.array([np.sum((w0 * points[:,0] + w1 - points[:,1]) * points[:,0]), np.sum(w0 * points[:,0] + w1 - points[:,1])])

# %% [markdown]
# Let us compute the gradient descent with backtracking

# %%
#Gradient descent with backtracking
def gradient_descent(w0,w1,thres):
  x_0=np.zeros(2)
  x_0[0]=w0
  x_0[1]=w1
  while True:
      alpha=1
      x_k=x_0-alpha*grad_Q(x_0[0],x_0[1])
      while Q(x_k[0],x_k[1])>=Q(x_0[0],x_0[1]):
        alpha=alpha/2
        x_k=x_0-alpha*grad_Q(x_0[0],x_0[1])
      if abs(Q(x_k[0],x_k[1]) - Q(x_0[0],x_0[1])) < thres:
        return x_k
      else:
        x_0=x_k
        
  return x_k

# %% [markdown]
# Let us apply the gradient descent to get the optimal parameters and plot the points and the linear regressor

# %%
#Apply the method and plot the result
w0=np.random.rand(1)
w1=np.random.rand(1)
w_opt = gradient_descent(w0,w1,1e-3)
print("The optimal parameters we obtained are:", w_opt)
x = np.linspace(-20,20,40)
y_hat= w_opt[0]*x+w_opt[1]
plt.scatter(points[:,0],points[:,1])
plt.plot(x,y_hat,'r')
# Out:
# The optimal parameters we obtained are: [1.01415369 0.20187762]

# %% [markdown]
# ### 2. Let us now check the sensitivity of the method to outliers. Change the value of one point to a value “far away” from the set of points, for instance points[1] = [-40,20].

# %%
#We add the outlier
#Let us apply the gradient descent to get the optimal parameters and plot the points and the line regressor
points[1]=[-40,20]
w0=np.random.rand(1)
w1=np.random.rand(1)
w_opt = gradient_descent(w0,w1,1e-3)
print("The optimal parameters we obtained are:", w_opt)
x = np.linspace(-40,40,80)
y_hat= w_opt[0]*x+w_opt[1]
plt.scatter(points[:,0],points[:,1])
plt.plot(x,y_hat,'r')
# Out:
# The optimal parameters we obtained are: [0.68421697 0.3193314 ]

# %% [markdown]
# We can see that adding one outlier, our linear regressor degenerates a bit. Let us see what happen if we put more outliers, for example ten

# %%
#We add 10 outliers and plot the result
for i in (np.random.rand(10)*100).astype(int):
    points[i] = (np.random.rand(2) - 0.5) * 80
w0=np.random.rand(1)
w1=np.random.rand(1)
w_opt = gradient_descent(w0,w1,1e-3)
print("The optimal parameters we obtained are:", w_opt)
x = np.linspace(-40,40,80)
y_hat= w_opt[0]*x+w_opt[1]
plt.scatter(points[:,0],points[:,1])
plt.plot(x,y_hat,'r')
# Out:
# The optimal parameters we obtained are: [0.43127653 0.34352946]

# %% [markdown]
# Notice that the linear regressor is strongly influenced by the outliers presence on the data sample.

# %% [markdown]
# ## 2. Robust functions

# %% [markdown]
# As we have seen previously, the least squares method (LSM) is hardly sensitive to outliers, i.e. samples that do not particularly contribute to fit the model.
#
# Let us consider a modification of the least squares error function, which will be given as follows:
# $$
# Q_C = \sum_{i=1}^m \rho(e_i),
# $$
# where $\rho(u)$ represents the Cauchy functions
# $$
# \rho(u) = \frac{c^2}{2} \text{ log } \Big[ 1+ \Big(\frac{u}{c} \Big)^2 \Big],
# $$
# with $c \in \mathbb{R}$.
#
# For the sake of simplicity, in the subsequent study we may consider $c =1$.

# %% [markdown]
# ###1 Plot the least squares function and compare it with the Cauchy function:

# %%
#Definitions of the functions we need
def ls_f(u):
    return 1/2 * u**2

def cauchy_f(u, c=1):
    return c**2/2 * np.log(1 + (u/c)**2)

# %%
#Plot of the least squares functions and the Cauchy function(red/blue) respectively
x=np.arange(-10,10, 0.1)
y_ls = ls_f(x)
y_c = cauchy_f(x)

plt.plot(x, y_ls, 'r')
plt.plot(x, y_c, 'b')

# %% [markdown]
# Note that we are considering the corresponding error function to represent the error given between each data sample and the corresponding prediction point using the model. Therefore, it is clear that the least squares initial (in red) function penalizes hardly the points that are actually further from the prediction, i.e. the outliers. Thus, intuitivelly it is direct to see that by considering the Cauchy function (in blue) as the error function may help the model adapt better in presence of outliers. Let's see a deepest study on this topic.

# %% [markdown]
# ### 2. Implement the algorithm that allows to compute the parameters $w_0, w_1$ using the Cauchy function

# %% [markdown]
# We may consider the backtracking gradient descent method as previously, using the least squares error function:
# $$
# Q_c = \sum_{i=1}^m \rho(e_i) = \frac{c^2}{2}  \sum_{i=1}^m \text{ log } \Big[ 1 + \Big( \frac{\hat{y}_i - y_i}{c} \Big)^2 \Big],
# $$
# where $\hat{y}_i = w_0 x_i + w_1$.

# %%
#Randomly generated set of points
m = [0.,0.]
angle = 45*math.pi/180
rot = np.array([[math.cos(angle), -math.sin(angle)], [math.sin(angle),
math.cos(angle)]])
lamb = np.array([[100,0],[0,1]])
s = np.matmul(rot, np.matmul(lamb, rot.transpose()))
points = np.random.multivariate_normal(m,s,100)
plt.scatter(points[:,0],points[:,1])

# %%
#Definitions of the functions we need
def Q_c(w0, w1, c=1):
    return (c**2/2) * np.sum( np.log(1 + ((w0 * points[:,0] + w1 - points[:,1])/c )**2))

def grad_Q_c(w0, w1, c=1):
    der_w0 = c**2 * np.sum( (1 +((w0 * points[:,0] + w1 - points[:,1])/c )**2 )**(-1)*(w0 * points[:,0] + w1 - points[:,1])/c  * points[:,0] )
    der_w1 = c**2 * np.sum( (1 +((w0 * points[:,0] + w1 - points[:,1])/c )**2 )**(-1)*(w0*points[:,0] +w1 - points[:,1]))
    return np.array([der_w0, der_w1])

# %%
#Gradient descent method using backtracking
def gradient_descent_c(w0,w1,thres,c=1):
    x_0=np.zeros(2)
    x_0[0]=w0
    x_0[1]=w1
    while True:
        alpha=1
        x_k=x_0-alpha*grad_Q_c(x_0[0],x_0[1], c)
        while Q_c(x_k[0],x_k[1], c)>=Q_c(x_0[0],x_0[1], c):
            alpha=alpha/2
            x_k=x_0-alpha*grad_Q_c(x_0[0],x_0[1], c)
        if abs(Q_c(x_k[0],x_k[1], c) - Q_c(x_0[0],x_0[1], c)) < thres:
            return x_k
        else:
            x_0=x_k

    return x_k

# %%
#Plot of the points and the linear regresor. We build a function for future use
def plot_prediction(gradient_descent, points):
    w0=np.random.rand(1)
    w1=np.random.rand(1)
    w_opt = gradient_descent(w0,w1,1e-3)
    print("The optimal parameters we obtained are:", w_opt)
    x = np.linspace(-20,20,40)
    y_hat= w_opt[0]*x+w_opt[1]
    plt.scatter(points[:,0],points[:,1])
    plt.plot(x,y_hat,'r')

# %%
#Linear regression using Cauchy function
plot_prediction(gradient_descent_c, points)
# Out:
# The optimal parameters we obtained are: [0.97613135 0.01192754]

# %% [markdown]
# ### 3. Compare the results obtained with the least squares function and with the Cauchy function, assuming that there are no outliers in the dataset.

# %%
#Linear regression using least square function
plot_prediction(gradient_descent, points)
# Out:
# The optimal parameters we obtained are: [1.00128506 0.05570983]

# %%
#Function that compare both methods
#Green--> Cauchy function
#red--> Least square function
def compare_plots(grad1, grad2, points):
    w0=np.random.rand(1)
    w1=np.random.rand(1)
    w_opt1 = grad1(w0,w1,1e-3)
    w_opt2 = grad2(w0,w1,1e-3)
    print("The optimal parameters we obtained with the least squares function are:", w_opt1)
    print("The optimal parameters we obtained with the Cauchy function are:", w_opt2)
    x = np.linspace(-20,20,40)
    y_hat1= w_opt1[0]*x+w_opt1[1]
    y_hat2= w_opt2[0]*x+w_opt2[1]
    plt.scatter(points[:,0],points[:,1])
    plt.plot(x,y_hat1,'r')
    plt.plot(x, y_hat2, 'g')

# %%
compare_plots(gradient_descent, gradient_descent_c, points)
# Out:
# The optimal parameters we obtained with the least squares function are: [0.99450236 0.12645818]
# The optimal parameters we obtained with the Cauchy function are: [0.97709388 0.05240405]

# %% [markdown]
# In absence of outliers, boths methods give really similar linear regressors. Let's consider cases with some outliers on the data samples.

# %% [markdown]
# ### 4. Compare now the results with only one outlier.

# %%
#We add the outlier
#Let us apply the gradient descent to get the optimal parameters and plot the points and the line regressor in both cases
points[1]=[-40,20]

# %%
#Plot of the points and the linear regresor. We build a function for future use, now taking into account that we will have outliers
def plot_prediction(gradient_descent, points):
    w0=np.random.rand(1)
    w1=np.random.rand(1)
    w_opt = gradient_descent(w0,w1,1e-3)
    print("The optimal parameters we obtained are:", w_opt)
    x = np.linspace(-40,40,80)
    y_hat= w_opt[0]*x+w_opt[1]
    plt.scatter(points[:,0],points[:,1])
    plt.plot(x,y_hat,'r')

# %%
#Linear regression using Cauchy function
plot_prediction(gradient_descent_c, points)
# Out:
# The optimal parameters we obtained are: [0.97136055 0.00309599]

# %%
#Linear regression using least square function
plot_prediction(gradient_descent, points)
# Out:
# The optimal parameters we obtained are: [0.59817867 0.84534749]

# %%
#Function that compare both methods, taking into account that we will have outliers
#Green--> Cauchy function
#red--> Least square function
def compare_plots(grad1, grad2, points):
    w0=np.random.rand(1)
    w1=np.random.rand(1)
    w_opt1 = grad1(w0,w1,1e-3)
    w_opt2 = grad2(w0,w1,1e-3)
    print("The optimal parameters we obtained with the least squares function are:", w_opt1)
    print("The optimal parameters we obtained with the Cauchy function are:", w_opt2)
    x = np.linspace(-40,40,80)
    y_hat1= w_opt1[0]*x+w_opt1[1]
    y_hat2= w_opt2[0]*x+w_opt2[1]
    plt.scatter(points[:,0],points[:,1])
    plt.plot(x,y_hat1,'r')
    plt.plot(x, y_hat2, 'g')

# %%
compare_plots(gradient_descent, gradient_descent_c, points)
# Out:
# The optimal parameters we obtained with the least squares function are: [0.60403799 0.90801297]
# The optimal parameters we obtained with the Cauchy function are: [0.97650993 0.07833032]

# %% [markdown]
# It is clear that the gradient descent method using the Cauchy function is less influenciable by the presence of outliers in the data samples. We can say the the gradient descent method using the Cauchy function is robuts in the presence of outliers.

# %% [markdown]
# ### 5. Check the results obtained with $c=1, c=100, c=1/100, c=1/1000$.

# %%
#Randomly generated set of points
m = [0.,0.]
angle = 45*math.pi/180
rot = np.array([[math.cos(angle), -math.sin(angle)], [math.sin(angle),
math.cos(angle)]])
lamb = np.array([[100,0],[0,1]])
s = np.matmul(rot, np.matmul(lamb, rot.transpose()))
points = np.random.multivariate_normal(m,s,100)
plt.scatter(points[:,0],points[:,1])

# %%
#Let us check the results for different values of c
c = [1, 100, 1/100, 1/1000]
colors = ['r', 'g', 'k', 'm']
w0=np.random.rand(1)
w1=np.random.rand(1)

for i in range(4):
    w_opt=gradient_descent_c(w0,w1,1e-3,c=c[i])
    print("The optimal parameters for c=",c[i],"are:", w_opt, "and we print it in color ",colors[i])
    x = np.linspace(-20,20,40)
    y_hat= w_opt[0]*x+w_opt[1]
    plt.scatter(points[:,0],points[:,1])
    plt.plot(x, y_hat, colors[i], label = c[i])
    plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
    plt.tight_layout()
    #plt.legend(loc="upper right")
# Out:
# The optimal parameters for c= 1 are: [0.99331494 0.23064897] and we print it in color  r
# The optimal parameters for c= 100 are: [0.98447594 0.24381082] and we print it in color  g
# The optimal parameters for c= 0.01 are: [0.69088872 0.23924312] and we print it in color  k
# The optimal parameters for c= 0.001 are: [0.690787  0.2392438] and we print it in color  m

# %% [markdown]
# Notice that, without introducing outliers, for small values of c, the linear regressor fits worse the points than for bigger values of c, as 1 o 1/10. Let us compute the  histogram of the error function |u|$= |\hat{y}_i - y_i|$ (its absolute value of u) and to compare with the shape corresponding to $\rho(u)$ functions.

# %% [markdown]
# We have computed the corresponding weigths for each value of $c$, we can use the corresponding $\hat{y}$ to draw the histogram of $|\hat{y}_i - y_i|$ and its Cauchy function value $\rho(\hat{y}_i - y_i$.

# %%
import altair as alt
import pandas as pd

#Let us check the results for different values of c
c = [1, 100, 1/100, 1/1000]
colors = ['b', 'g', 'k', 'm']
w0=np.random.rand(1)
w1=np.random.rand(1)

y_hat= np.zeros((4, 100))
y_hat_i = np.zeros((4, 100))


chart = alt.vconcat()
for i in range(4):
    w_opt=gradient_descent_c(w0,w1,1e-3,c=c[i])
    print("The optimal parameters for c=",c[i],"are:", w_opt, "and we print it in color ",colors[i])
    x = np.linspace(-20,20,100)
    y_hat[i]= w_opt[0]*x+w_opt[1]
    y_hat_i[i]= w_opt[0]*points[:,0]+w_opt[1]
    plt.scatter(points[:,0],points[:,1])
    plt.plot(x, y_hat[i], colors[i], label = c[i])
    plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
    plt.tight_layout()
    #plt.legend(loc="upper right")
    
    source = pd.DataFrame({
        'abs_u' : abs(y_hat_i[i] - points[:,1])
        #'cau_u' : Q_c(w_opt[0],w_opt[1], c[i])
    })
    histogram = alt.Chart(source).mark_bar().encode(
        alt.X("abs_u:Q", bin = alt.Bin( step=0.5)), #bin=True),
        #x='abs_u',
        y='count()'
    )
    chart &= histogram
# Out:
# The optimal parameters for c= 1 are: [0.99106457 0.25137307] and we print it in color  b
# The optimal parameters for c= 100 are: [0.9844752  0.24365297] and we print it in color  g
# The optimal parameters for c= 0.01 are: [0.66345018 0.5913559 ] and we print it in color  k
# The optimal parameters for c= 0.001 are: [0.66310571 0.5913558 ] and we print it in color  m

# %%
#source

# %%
chart
# Out:
# /Users/flaviaferrusmarimon/anaconda3/lib/python3.9/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.VConcatChart(...)

# %%
def Q_c_general(u, c=1):
    return (c**2/2) *  np.log(1 + (u/c )**2)


u_general = np.linspace(-10,10,100)
chart2 = alt.vconcat()
for i in range(4):
    source = pd.DataFrame({
        'cauchy_u' : Q_c_general(u_general, c[i])
    })
    histogram = alt.Chart(source).mark_bar().encode(
        alt.X("cauchy_u:Q", bin=True), #bin = alt.Bin( step=0.5)), #
        #x='abs_u',
        y='count()'
    )
    chart2 &= histogram

# %%
chart2
# Out:
# /Users/flaviaferrusmarimon/anaconda3/lib/python3.9/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.VConcatChart(...)

# %%
source
# Out:
#     cauchy_u
# 0   0.000009
# 1   0.000009
# 2   0.000009
# 3   0.000009
# 4   0.000009
# ..       ...
# 95  0.000009
# 96  0.000009
# 97  0.000009
# 98  0.000009
# 99  0.000009
#
# [100 rows x 1 columns]

# %%
for i in range(4):
    print(Q_c_general(u_general, c[i]))
# Out:
# [2.30756026 2.28735759 2.26674278 2.24569885 2.22420777 2.20225037
#  2.17980624 2.15685361 2.13336924 2.10932829 2.08470418 2.0594684
#  2.03359033 2.00703705 1.97977311 1.95176024 1.92295708 1.89331884
#  1.86279693 1.8313385  1.798886   1.76537659 1.73074152 1.69490541
#  1.6577854  1.61929021 1.57931904 1.53776033 1.49449031 1.4493714
#  1.40225031 1.35295604 1.3012976  1.24706165 1.19001014 1.12987831
#  1.06637364 0.99917677 0.92794649 0.8523323  0.77200124 0.68669051
#  0.59630688 0.5011083  0.40202394 0.30118608 0.20271555 0.11359807
#  0.04392639 0.00507567 0.00507567 0.04392639 0.11359807 0.20271555
#  0.30118608 0.40202394 0.5011083  0.59630688 0.68669051 0.77200124
#  0.8523323  0.92794649 0.99917677 1.06637364 1.12987831 1.19001014
#  1.24706165 1.3012976  1.35295604 1.40225031 1.4493714  1.49449031
#  1.53776033 1.57931904 1.61929021 1.6577854  1.69490541 1.73074152
#  1.76537659 1.798886   1.8313385  1.86279693 1.89331884 1.92295708
#  1.95176024 1.97977311 2.00703705 2.03359033 2.0594684  2.08470418
#  2.10932829 2.13336924 2.15685361 2.17980624 2.20225037 2.22420777
#  2.24569885 2.26674278 2.28735759 2.30756026]
# [4.97516543e+01 4.77712661e+01 4.58305333e+01 4.39295021e+01
#  4.20682183e+01 4.02467265e+01 3.84650705e+01 3.67232930e+01
#  3.50214361e+01 3.33595406e+01 3.17376466e+01 3.01557933e+01
#  2.86140188e+01 2.71123604e+01 2.56508543e+01 2.42295359e+01
#  2.28484397e+01 2.15075990e+01 2.02070463e+01 1.89468133e+01
#  1.77269304e+01 1.65474273e+01 1.54083327e+01 1.43096742e+01
#  1.32514785e+01 1.22337714e+01 1.12565777e+01 1.03199211e+01
#  9.42382452e+00 8.56830976e+00 7.75339768e+00 6.97910816e+00
#  6.24546011e+00 5.55247142e+00 4.90015902e+00 4.28853885e+00
#  3.71762585e+00 3.18743397e+00 2.69797618e+00 2.24926444e+00
#  1.84130973e+00 1.47412203e+00 1.14771032e+00 8.62082600e-01
#  6.17245850e-01 4.13206066e-01 2.49968244e-01 1.27536380e-01
#  4.59134715e-02 5.10151765e-03 5.10151765e-03 4.59134715e-02
#  1.27536380e-01 2.49968244e-01 4.13206066e-01 6.17245850e-01
#  8.62082600e-01 1.14771032e+00 1.47412203e+00 1.84130973e+00
#  2.24926444e+00 2.69797618e+00 3.18743397e+00 3.71762585e+00
#  4.28853885e+00 4.90015902e+00 5.55247142e+00 6.24546011e+00
#  6.97910816e+00 7.75339768e+00 8.56830976e+00 9.42382452e+00
#  1.03199211e+01 1.12565777e+01 1.22337714e+01 1.32514785e+01
#  1.43096742e+01 1.54083327e+01 1.65474273e+01 1.77269304e+01
#  1.89468133e+01 2.02070463e+01 2.15075990e+01 2.28484397e+01
#  2.42295359e+01 2.56508543e+01 2.71123604e+01 2.86140188e+01
#  3.01557933e+01 3.17376466e+01 3.33595406e+01 3.50214361e+01
#  3.67232930e+01 3.84650705e+01 4.02467265e+01 4.20682183e+01
#  4.39295021e+01 4.58305333e+01 4.77712661e+01 4.97516543e+01]
# [0.00069078 0.00068873 0.00068665 0.00068452 0.00068235 0.00068013
#  0.00067785 0.00067553 0.00067315 0.00067071 0.00066821 0.00066564
#  0.00066301 0.00066031 0.00065753 0.00065467 0.00065173 0.0006487
#  0.00064558 0.00064235 0.00063902 0.00063557 0.000632   0.00062829
#  0.00062445 0.00062045 0.00061628 0.00061193 0.00060738 0.00060262
#  0.00059762 0.00059236 0.0005868  0.00058091 0.00057466 0.00056799
#  0.00056085 0.00055315 0.00054481 0.00053572 0.00052571 0.00051459
#  0.00050207 0.00048776 0.00047106 0.00045099 0.00042586 0.00039223
#  0.00034118 0.00023175 0.00023175 0.00034118 0.00039223 0.00042586
#  0.00045099 0.00047106 0.00048776 0.00050207 0.00051459 0.00052571
#  0.00053572 0.00054481 0.00055315 0.00056085 0.00056799 0.00057466
#  0.00058091 0.0005868  0.00059236 0.00059762 0.00060262 0.00060738
#  0.00061193 0.00061628 0.00062045 0.00062445 0.00062829 0.000632
#  0.00063557 0.00063902 0.00064235 0.00064558 0.0006487  0.00065173
#  0.00065467 0.00065753 0.00066031 0.00066301 0.00066564 0.00066821
#  0.00067071 0.00067315 0.00067553 0.00067785 0.00068013 0.00068235
#  0.00068452 0.00068665 0.00068873 0.00069078]
# [9.21034038e-06 9.18993151e-06 9.16909742e-06 9.14782002e-06
#  9.12608003e-06 9.10385690e-06 9.08112865e-06 9.05787179e-06
#  9.03406114e-06 9.00966968e-06 8.98466838e-06 8.95902595e-06
#  8.93270864e-06 8.90567997e-06 8.87790041e-06 8.84932704e-06
#  8.81991315e-06 8.78960780e-06 8.75835526e-06 8.72609440e-06
#  8.69275798e-06 8.65827180e-06 8.62255372e-06 8.58551245e-06
#  8.54704617e-06 8.50704084e-06 8.46536815e-06 8.42188304e-06
#  8.37642066e-06 8.32879262e-06 8.27878220e-06 8.22613847e-06
#  8.17056862e-06 8.11172813e-06 8.04920778e-06 7.98251641e-06
#  7.91105746e-06 7.83409643e-06 7.75071483e-06 7.65974307e-06
#  7.55965964e-06 7.44843404e-06 7.32327094e-06 7.18017017e-06
#  7.01311620e-06 6.81244570e-06 6.56113167e-06 6.22466039e-06
#  5.71383826e-06 4.61526952e-06 4.61526952e-06 5.71383826e-06
#  6.22466039e-06 6.56113167e-06 6.81244570e-06 7.01311620e-06
#  7.18017017e-06 7.32327094e-06 7.44843404e-06 7.55965964e-06
#  7.65974307e-06 7.75071483e-06 7.83409643e-06 7.91105746e-06
#  7.98251641e-06 8.04920778e-06 8.11172813e-06 8.17056862e-06
#  8.22613847e-06 8.27878220e-06 8.32879262e-06 8.37642066e-06
#  8.42188304e-06 8.46536815e-06 8.50704084e-06 8.54704617e-06
#  8.58551245e-06 8.62255372e-06 8.65827180e-06 8.69275798e-06
#  8.72609440e-06 8.75835526e-06 8.78960780e-06 8.81991315e-06
#  8.84932704e-06 8.87790041e-06 8.90567997e-06 8.93270864e-06
#  8.95902595e-06 8.98466838e-06 9.00966968e-06 9.03406114e-06
#  9.05787179e-06 9.08112865e-06 9.10385690e-06 9.12608003e-06
#  9.14782002e-06 9.16909742e-06 9.18993151e-06 9.21034038e-06]

# %% [markdown]
# ### 6.The Cauchy function is not “perfect”, and it is not robust for any number of outliers. For c=1 and c=1/100.  You should see that for a certain number of outliers, the the Cauchy function will be sensitive to the “high” number of outliers.

# %% [markdown]
# We study first the case c=1. We will study the linear regressor when adding 10%,33%,50%,75% of outliers. We plot two differents charts. The first one, the linear regressor computed  with the points adding the outliers and the second one, the same linear regressor, computed with the points adding the outliers, but plotting in with the original points, without outleirs, to see the degenerations of the linear regressor

# %%
#We add 10 outliers(10% outliers)
c=1
points_original=points
points=np.copy(points_original)
for i in range(0,100,10):
  points[i] = (np.random.rand(2)-0.5) * 100

w0=np.random.rand(1)
w1=np.random.rand(1)
w_opt = gradient_descent_c(w0,w1,1e-3)
print("The optimal parameters we obtained are:", w_opt)
x = np.linspace(-40,40,80)
y_hat= w_opt[0]*x+w_opt[1]
fig,(ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(points[:,0],points[:,1]) 
ax1.plot(x,y_hat,'r')
ax2.scatter(points_original[:,0],points_original[:,1]) 
ax2.plot(x,y_hat,'r')
# Out:
# The optimal parameters we obtained are: [ 0.92999656 -0.12408181]

# %%
#We add 33 outliers(33% outliers)
c=1
points=np.copy(points_original)
for i in range(0,100,3):
  points[i] = (np.random.rand(2)-0.5) * 100

w0=np.random.rand(1)
w1=np.random.rand(1)
w_opt = gradient_descent_c(w0,w1,1e-3)
print("The optimal parameters we obtained are:", w_opt)
x = np.linspace(-40,40,80)
y_hat= w_opt[0]*x+w_opt[1]
fig,(ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(points[:,0],points[:,1]) 
ax1.plot(x,y_hat,'r')
ax2.scatter(points_original[:,0],points_original[:,1]) 
ax2.plot(x,y_hat,'r')
# Out:
# The optimal parameters we obtained are: [ 0.93396345 -0.15366399]

# %%
#We add 50 outliers(50% outliers)
c=1
points=np.copy(points_original)
for i in range(0,100,2):
  points[i] = (np.random.rand(2)-0.5) * 100

w0=np.random.rand(1)
w1=np.random.rand(1)
w_opt = gradient_descent_c(w0,w1,1e-3)
print("The optimal parameters we obtained are:", w_opt)
x = np.linspace(-40,40,80)
y_hat= w_opt[0]*x+w_opt[1]
fig,(ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(points[:,0],points[:,1]) 
ax1.plot(x,y_hat,'r')
ax2.scatter(points_original[:,0],points_original[:,1]) 
ax2.plot(x,y_hat,'r')
# Out:
# The optimal parameters we obtained are: [0.8510794  0.71468092]

# %%
#We add 75 outliers(75% outliers)
c=1
for i in range(0,100):
  points[i] = (np.random.rand(2)-0.5) * 100
for i in range(0,100,4):
  points[i]=points_original[i]
w0=np.random.rand(1)
w1=np.random.rand(1)
w_opt = gradient_descent_c(w0,w1,1e-3)
print("The optimal parameters we obtained are:", w_opt)
x = np.linspace(-40,40,80)
y_hat= w_opt[0]*x+w_opt[1]
fig,(ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(points[:,0],points[:,1]) 
ax1.plot(x,y_hat,'r')
ax2.scatter(points_original[:,0],points_original[:,1]) 
ax2.plot(x,y_hat,'r')
# Out:
# The optimal parameters we obtained are: [-0.23380921  0.4034379 ]

# %% [markdown]
# In this case, the linear regressor is robust. When the percentage of the outliers are less than the 50%, the linear regressor fits well the data. We we put 75% of outliers, the linear regressor performs really bad, but it is not surpising, we only have 25% of the points that follows a distribution, it is really difficult for the linear regressor to capt the distribution.

# %%
#Randomly generated set of points
m = [0.,0.]
angle = 45*math.pi/180
rot = np.array([[math.cos(angle), -math.sin(angle)], [math.sin(angle),
math.cos(angle)]])
lamb = np.array([[100,0],[0,1]])
s = np.matmul(rot, np.matmul(lamb, rot.transpose()))
points = np.random.multivariate_normal(m,s,100)
plt.scatter(points[:,0],points[:,1])

# %%
#We add 10 outliers(10% outliers)
c=1/100
points_original=points
points=np.copy(points_original)
for i in range(0,100,10):
  points[i] = (np.random.rand(2)-0.5) * 100

w0=np.random.rand(1)
w1=np.random.rand(1)
w_opt = gradient_descent_c(w0,w1,1e-3,c=1/100)
print("The optimal parameters we obtained are:", w_opt)
x = np.linspace(-40,40,80)
y_hat= w_opt[0]*x+w_opt[1]
fig,(ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(points[:,0],points[:,1]) 
ax1.plot(x,y_hat,'r')
ax2.scatter(points_original[:,0],points_original[:,1]) 
ax2.plot(x,y_hat,'r')
# Out:
# The optimal parameters we obtained are: [0.59672457 0.57811017]

# %%
#We add 33 outliers(33% outliers)
c=1/100
points=np.copy(points_original)
for i in range(0,100,3):
  points[i] = (np.random.rand(2)-0.5) * 100

w0=np.random.rand(1)
w1=np.random.rand(1)
w_opt = gradient_descent_c(w0,w1,1e-3,c=1/100)
print("The optimal parameters we obtained are:", w_opt)
x = np.linspace(-40,40,80)
y_hat= w_opt[0]*x+w_opt[1]
fig,(ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(points[:,0],points[:,1]) 
ax1.plot(x,y_hat,'r')
ax2.scatter(points_original[:,0],points_original[:,1]) 
ax2.plot(x,y_hat,'r')
# Out:
# The optimal parameters we obtained are: [0.62415156 0.36899051]

# %%
#We add 50 outliers(50% outliers)
c=1/100
points=np.copy(points_original)
for i in range(0,100,2):
  points[i] = (np.random.rand(2)-0.5) * 100

w0=np.random.rand(1)
w1=np.random.rand(1)
w_opt = gradient_descent_c(w0,w1,1e-3,c=1/100)
print("The optimal parameters we obtained are:", w_opt)
x = np.linspace(-40,40,80)
y_hat= w_opt[0]*x+w_opt[1]
fig,(ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(points[:,0],points[:,1]) 
ax1.plot(x,y_hat,'r')
ax2.scatter(points_original[:,0],points_original[:,1]) 
ax2.plot(x,y_hat,'r')
# Out:
# The optimal parameters we obtained are: [0.08201916 0.16757178]

# %%
#We add 75 outliers(75% outliers)
c=1/100
for i in range(0,100):
  points[i] = (np.random.rand(2)-0.5) * 100
for i in range(0,100,4):
  points[i]=points_original[i]
w0=np.random.rand(1)
w1=np.random.rand(1)
w_opt = gradient_descent_c(w0,w1,1e-3,c=1/100)
print("The optimal parameters we obtained are:", w_opt)
x = np.linspace(-40,40,80)
y_hat= w_opt[0]*x+w_opt[1]
fig,(ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(points[:,0],points[:,1]) 
ax1.plot(x,y_hat,'r')
ax2.scatter(points_original[:,0],points_original[:,1]) 
ax2.plot(x,y_hat,'r')
# Out:
# The optimal parameters we obtained are: [0.54584465 0.07002997]

# %% [markdown]
# For this small value of c, the linear regressor does not fits the data even with 10% of outliers. The method is not robust in that case.
